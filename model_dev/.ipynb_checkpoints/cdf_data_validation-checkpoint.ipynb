# %%
import cdflib # https://github.com/MAVENSDC/cdflib

# %%
cdf_file_1 = cdflib.CDF('cdf_data/M1279A1_XX016536516794165_20210520_1323_JLTV_B_TS_Daily.cdf')

# %%
cdf_file_1.cdf_info()
# Out:
# {'CDF': WindowsPath('C:/Users/hamsh/AppData/Local/Temp/tmpwn0ow2x1.cdf'),
#  'Version': '3.4.1',
#  'Encoding': 6,
#  'Majority': 'Row_major',
#  'rVariables': [],
#  'zVariables': ['UTC_1Hz',
#   'BrakeSwitch',
#   'CrankcasePres',
#   'TrOutShaftSp',
#   'ASREngCtlActive',
#   'ABSActive',
#   'FuelRate',
#   'IntManfTemp',
#   'EngCoolantTemp',
#   'ABS_OffRoadSwtchStatBrakes',
#   'InjCtlPres',
#   'PctEngLoad',
#   'InstFuelEco',
#   'ProgShftDisable',
#   'ASROffRoadSwtchBrake',
#   'ParkBrkSwtchStatEng',
#   'TrSelGr',
#   'ClutchSwtch',
#   'EngOilPres',
#   'RetEnableBrkAsstSwtchRetExhaust',
#   'EngPctTorq',
#   'EBSBrkSwtch',
#   'TransDrivEng',
#   'TractionCtrlOverrideSwtch_Brakes',
#   'TransCurGear',
#   'BatPotVBrake_1587',
#   'RelativeSpdRearAxle1RghtWheel',
#   'RelativeSpdFrontAxleLftWheel',
#   'AccelPedalPos',
#   'PTOGovernorState',
#   'BoostPres',
#   'RelativeSpdRearAxle2RghtWheel',
#   'FrontAxleSpd',
#   'TrRgSelec',
#   'EngSpeed',
#   'AirInletTemp',
# ...

# %%
cdf_file_2 = cdflib.CDF('cdf_data/M1279A1_XX016536516794165_20210518_1215_JLTV_B_TS_Daily.cdf')
cdf_file_2.cdf_info()
# Out:
# {'CDF': WindowsPath('C:/Users/hamsh/AppData/Local/Temp/tmpsw2lymr8.cdf'),
#  'Version': '3.4.1',
#  'Encoding': 6,
#  'Majority': 'Row_major',
#  'rVariables': [],
#  'zVariables': ['UTC_1Hz',
#   'BrakeSwitch',
#   'CrankcasePres',
#   'TrOutShaftSp',
#   'ASREngCtlActive',
#   'ABSActive',
#   'FuelRate',
#   'IntManfTemp',
#   'EngCoolantTemp',
#   'ABS_OffRoadSwtchStatBrakes',
#   'InjCtlPres',
#   'PctEngLoad',
#   'InstFuelEco',
#   'ProgShftDisable',
#   'ASROffRoadSwtchBrake',
#   'ParkBrkSwtchStatEng',
#   'TrSelGr',
#   'ClutchSwtch',
#   'EngOilPres',
#   'RetEnableBrkAsstSwtchRetExhaust',
#   'EngPctTorq',
#   'EBSBrkSwtch',
#   'TransDrivEng',
#   'TractionCtrlOverrideSwtch_Brakes',
#   'TransCurGear',
#   'BatPotVBrake_1587',
#   'RelativeSpdRearAxle1RghtWheel',
#   'RelativeSpdFrontAxleLftWheel',
#   'AccelPedalPos',
#   'PTOGovernorState',
#   'BoostPres',
#   'RelativeSpdRearAxle2RghtWheel',
#   'FrontAxleSpd',
#   'TrRgSelec',
#   'EngSpeed',
#   'AirInletTemp',
# ...

# %%
cdf_file_3 = cdflib.CDF('cdf_data/M1279A1_XX016536516794165_20201021_1459_JLTV_B_TS_Daily.cdf')
cdf_file_3.cdf_info()
# Out:
# {'CDF': WindowsPath('C:/Users/hamsh/AppData/Local/Temp/tmpocy2t6s4.cdf'),
#  'Version': '3.4.1',
#  'Encoding': 6,
#  'Majority': 'Row_major',
#  'rVariables': [],
#  'zVariables': ['UTC_1Hz',
#   'BrakeSwitch',
#   'CrankcasePres',
#   'TrOutShaftSp',
#   'ASREngCtlActive',
#   'ABSActive',
#   'FuelRate',
#   'IntManfTemp',
#   'EngCoolantTemp',
#   'ABS_OffRoadSwtchStatBrakes',
#   'InjCtlPres',
#   'PctEngLoad',
#   'InstFuelEco',
#   'ProgShftDisable',
#   'ASROffRoadSwtchBrake',
#   'ParkBrkSwtchStatEng',
#   'TrSelGr',
#   'ClutchSwtch',
#   'EngOilPres',
#   'RetEnableBrkAsstSwtchRetExhaust',
#   'EngPctTorq',
#   'EBSBrkSwtch',
#   'TransDrivEng',
#   'TractionCtrlOverrideSwtch_Brakes',
#   'TransCurGear',
#   'BatPotVBrake_1587',
#   'RelativeSpdRearAxle1RghtWheel',
#   'RelativeSpdFrontAxleLftWheel',
#   'AccelPedalPos',
#   'PTOGovernorState',
#   'BoostPres',
#   'RelativeSpdRearAxle2RghtWheel',
#   'FrontAxleSpd',
#   'TrRgSelec',
#   'EngSpeed',
#   'AirInletTemp',
# ...

# %%
cdf_file_4 = cdflib.CDF('cdf_data/M1279A1_XX016536516794165_20201019_1311_JLTV_B_TS_Daily.cdf')
cdf_file_4.cdf_info()
# Out:
# {'CDF': WindowsPath('C:/Users/hamsh/AppData/Local/Temp/tmpo46boqm0.cdf'),
#  'Version': '3.4.1',
#  'Encoding': 6,
#  'Majority': 'Row_major',
#  'rVariables': [],
#  'zVariables': ['UTC_1Hz',
#   'BrakeSwitch',
#   'CrankcasePres',
#   'TrOutShaftSp',
#   'ASREngCtlActive',
#   'ABSActive',
#   'FuelRate',
#   'IntManfTemp',
#   'EngCoolantTemp',
#   'ABS_OffRoadSwtchStatBrakes',
#   'InjCtlPres',
#   'PctEngLoad',
#   'InstFuelEco',
#   'ProgShftDisable',
#   'ASROffRoadSwtchBrake',
#   'ParkBrkSwtchStatEng',
#   'TrSelGr',
#   'ClutchSwtch',
#   'EngOilPres',
#   'RetEnableBrkAsstSwtchRetExhaust',
#   'EngPctTorq',
#   'EBSBrkSwtch',
#   'TransDrivEng',
#   'TractionCtrlOverrideSwtch_Brakes',
#   'TransCurGear',
#   'BatPotVBrake_1587',
#   'RelativeSpdRearAxle1RghtWheel',
#   'RelativeSpdFrontAxleLftWheel',
#   'AccelPedalPos',
#   'PTOGovernorState',
#   'BoostPres',
#   'RelativeSpdRearAxle2RghtWheel',
#   'FrontAxleSpd',
#   'TrRgSelec',
#   'EngSpeed',
#   'AirInletTemp',
# ...

# %%
cdf_file_5 = cdflib.CDF('cdf_data/2AMK23A1_XX015520273598222_20201028_1524_MTVR_B_TS_Daily.cdf')
cdf_file_5.cdf_info()
# Out:
# {'CDF': WindowsPath('C:/Users/hamsh/AppData/Local/Temp/tmpg_yau_ny.cdf'),
#  'Version': '3.4.1',
#  'Encoding': 6,
#  'Majority': 'Row_major',
#  'rVariables': [],
#  'zVariables': ['UTC_1Hz',
#   'BrakeSwitch',
#   'CrankcasePres',
#   'TrOutShaftSp',
#   'AuxHeatModeReq',
#   'ASREngCtlActive',
#   'ABSActive',
#   'FuelRate',
#   'IntManfTemp',
#   'PTOSetSpeed_1587',
#   'EngCoolantTemp',
#   'EngOilTemp_1587',
#   'ABS_OffRoadSwtchStatBrakes',
#   'SeatBeltSwtch',
#   'PctEngLoad',
#   'InstFuelEco',
#   'ProgShftDisable',
#   'ASROffRoadSwtchBrake',
#   'TrRgAttai',
#   'RetTorqModeEng',
#   'ParkBrkSwtchStatEng',
#   'TrSelGr',
#   'BarPres_Eng_1587',
#   'ClutchSwtch',
#   'EngOilPres',
#   'EngPctTorq',
#   'EngOilTemp',
#   'EBSBrkSwtch',
#   'TransDrivEng',
#   'Cylinder6EngRetStat_1587',
#   'Avg_FuelEco_1587',
#   'TractionCtrlOverrideSwtch_Brakes',
#   'RetEnableBrkAsstSwtchRetEng',
#   'BatPotVBrake_1587',
#   'RelativeSpdRearAxle1RghtWheel',
#   'OpSeatDirSwtch',
# ...

# %%
cdf_file_6 = cdflib.CDF('cdf_data/2AMK23A1_XX015520273598222_20201019_1308_MTVR_B_TS_Daily.cdf')
cdf_file_6.cdf_info()
# Out:
# {'CDF': WindowsPath('C:/Users/hamsh/AppData/Local/Temp/tmprmcz7w__.cdf'),
#  'Version': '3.4.1',
#  'Encoding': 6,
#  'Majority': 'Row_major',
#  'rVariables': [],
#  'zVariables': ['UTC_1Hz',
#   'BrakeSwitch',
#   'CrankcasePres',
#   'TrOutShaftSp',
#   'AuxHeatModeReq',
#   'ASREngCtlActive',
#   'ABSActive',
#   'FuelRate',
#   'IntManfTemp',
#   'PTOSetSpeed_1587',
#   'EngCoolantTemp',
#   'EngOilTemp_1587',
#   'ABS_OffRoadSwtchStatBrakes',
#   'SeatBeltSwtch',
#   'PctEngLoad',
#   'InstFuelEco',
#   'ProgShftDisable',
#   'ASROffRoadSwtchBrake',
#   'TrRgAttai',
#   'RetTorqModeEng',
#   'ParkBrkSwtchStatEng',
#   'TrSelGr',
#   'BarPres_Eng_1587',
#   'ClutchSwtch',
#   'EngOilPres',
#   'EngPctTorq',
#   'EngOilTemp',
#   'EBSBrkSwtch',
#   'TransDrivEng',
#   'Cylinder6EngRetStat_1587',
#   'Avg_FuelEco_1587',
#   'TractionCtrlOverrideSwtch_Brakes',
#   'RetEnableBrkAsstSwtchRetEng',
#   'BatPotVBrake_1587',
#   'RelativeSpdRearAxle1RghtWheel',
#   'OpSeatDirSwtch',
# ...

# %%
cdf_file_7 = cdflib.CDF('cdf_data/2AMK23A1_XX015520273598222_20201015_1019_MTVR_B_TS_Daily.cdf')
cdf_file_7.cdf_info()
# Out:
# {'CDF': WindowsPath('C:/Users/hamsh/AppData/Local/Temp/tmp3_tlah9o.cdf'),
#  'Version': '3.4.1',
#  'Encoding': 6,
#  'Majority': 'Row_major',
#  'rVariables': [],
#  'zVariables': ['UTC_1Hz',
#   'BrakeSwitch',
#   'CrankcasePres',
#   'TrOutShaftSp',
#   'AuxHeatModeReq',
#   'ASREngCtlActive',
#   'ABSActive',
#   'FuelRate',
#   'IntManfTemp',
#   'PTOSetSpeed_1587',
#   'EngCoolantTemp',
#   'EngOilTemp_1587',
#   'ABS_OffRoadSwtchStatBrakes',
#   'SeatBeltSwtch',
#   'PctEngLoad',
#   'InstFuelEco',
#   'ProgShftDisable',
#   'ASROffRoadSwtchBrake',
#   'TrRgAttai',
#   'RetTorqModeEng',
#   'ParkBrkSwtchStatEng',
#   'TrSelGr',
#   'BarPres_Eng_1587',
#   'ClutchSwtch',
#   'EngOilPres',
#   'EngPctTorq',
#   'EngOilTemp',
#   'EBSBrkSwtch',
#   'TransDrivEng',
#   'Cylinder6EngRetStat_1587',
#   'Avg_FuelEco_1587',
#   'TractionCtrlOverrideSwtch_Brakes',
#   'RetEnableBrkAsstSwtchRetEng',
#   'BatPotVBrake_1587',
#   'RelativeSpdRearAxle1RghtWheel',
#   'OpSeatDirSwtch',
# ...
